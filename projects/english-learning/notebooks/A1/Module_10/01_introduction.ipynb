# %% [markdown]
# # Module 10: Prepositions of Place and Time - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **In, On, At for Location and Time**
#
# ### Learning Objectives
#
# - In/on/at for place (in the room, on the table, at home)
# - In/on/at for time (in May, on Monday, at 3pm)
# - Other place prepositions (under, behind, next to, between)
# - Common expressions with prepositions
# - Preposition usage rules
#
# ### Time Requirement
# ⏱️ Estimated time: 6-8 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Master basic prepositions to describe location and time
#
# ---
#
# ## Key Concepts
#
# - In/on/at for place (in the room, on the table, at home)
# - In/on/at for time (in May, on Monday, at 3pm)
# - Other place prepositions (under, behind, next to, between)
# - Common expressions with prepositions
# - Preposition usage rules
#
# ---
#
# ## Examples
#
# ### Example 1: The book is on the table.
# **Place**
#
# ### Example 2: I live in London.
# **Place - city**
#
# ### Example 3: The meeting is at 5 o'clock.
# **Time**
#
# ### Example 4: My birthday is in June.
# **Time - month**
#
# ### Example 5: The cat is under the chair.
# **Place**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
