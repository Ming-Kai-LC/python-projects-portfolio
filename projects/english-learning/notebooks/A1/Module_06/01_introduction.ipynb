# %% [markdown]
# # Module 06: Nouns and Plurals - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **Regular and Irregular Plural Forms**
#
# ### Learning Objectives
#
# - Regular plurals (-s: cats, dogs)
# - Plurals with -es (box→boxes, dish→dishes)
# - Plurals with -ies (city→cities)
# - Irregular plurals (man→men, child→children)
# - Countable vs uncountable nouns
#
# ### Time Requirement
# ⏱️ Estimated time: 6-8 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Learn to form plural nouns, both regular (-s/-es) and irregular forms
#
# ---
#
# ## Key Concepts
#
# - Regular plurals (-s: cats, dogs)
# - Plurals with -es (box→boxes, dish→dishes)
# - Plurals with -ies (city→cities)
# - Irregular plurals (man→men, child→children)
# - Countable vs uncountable nouns
#
# ---
#
# ## Examples
#
# ### Example 1: One cat, two cats
# **Regular plural**
#
# ### Example 2: One box, two boxes
# **Plural -es**
#
# ### Example 3: One city, two cities
# **Plural -ies**
#
# ### Example 4: One child, two children
# **Irregular**
#
# ### Example 5: Water is uncountable
# **No plural form**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
