# %% [markdown]
# # Module 6: Nouns and Plurals - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the controlled practice phase! Here you'll complete **58 exercises** with immediate feedback to master plural formation.
#
# ### What You'll Practice:
# - ✅ Regular plurals (add -s)
# - ✅ Plurals with -es (after s/x/z/ch/sh)
# - ✅ Consonant + y → ies
# - ✅ Vowel + y → ys
# - ✅ F/FE → ves
# - ✅ Irregular plurals (man→men, child→children)
# - ✅ Same-form plurals (sheep→sheep)
# - ✅ Countable vs uncountable nouns
# - ✅ Error correction
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys
sys.path.append('../../../utils')

from feedback_system import ExerciseValidator, InteractiveExercise
from IPython.display import display, HTML

# Initialize the exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice plural formation!")
print("📊 Your progress will be tracked automatically.")
print("\n💡 Tip: Pay attention to the ending of each noun!")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Regular Plurals (Add -s) 📌
#
# **Rule**: For most nouns, just add **-s** to make the plural.
#
# **Example**: cat → cats, dog → dogs
#
# Write the plural form of each noun.
#
# ---

# %%
# Exercise Set 1: Regular Plurals

display(HTML('<h3>Exercise 1</h3>'))
display(HTML('<p><strong>Singular:</strong> book</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: book → ___",
    "books"
)

display(HTML('<h3>Exercise 2</h3>'))
display(HTML('<p><strong>Singular:</strong> car</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: car → ___",
    "cars"
)

display(HTML('<h3>Exercise 3</h3>'))
display(HTML('<p><strong>Singular:</strong> table</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: table → ___",
    "tables"
)

display(HTML('<h3>Exercise 4</h3>'))
display(HTML('<p><strong>Singular:</strong> computer</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: computer → ___",
    "computers"
)

display(HTML('<h3>Exercise 5</h3>'))
display(HTML('<p><strong>Singular:</strong> friend</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: friend → ___",
    "friends"
)

display(HTML('<h3>Exercise 6</h3>'))
display(HTML('<p><strong>Singular:</strong> phone</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: phone → ___",
    "phones"
)

display(HTML('<h3>Exercise 7</h3>'))
display(HTML('<p>I have two ___ (pen).</p>'))
exercise.create_fill_in_blank(
    "Answer: I have two ___ (pen).",
    "pens"
)

print("\n✅ Exercise Set 1 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 2: Plurals with -es 📦
#
# **Rule**: Add **-es** after nouns ending in **-s, -x, -z, -ch, -sh**.
#
# **Example**: box → boxes, dish → dishes
#
# Write the plural form.
#
# ---

# %%
# Exercise Set 2: Plurals with -es

display(HTML('<h3>Exercise 8</h3>'))
display(HTML('<p><strong>Singular:</strong> box</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: box → ___",
    "boxes"
)

display(HTML('<h3>Exercise 9</h3>'))
display(HTML('<p><strong>Singular:</strong> bus</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: bus → ___",
    "buses"
)

display(HTML('<h3>Exercise 10</h3>'))
display(HTML('<p><strong>Singular:</strong> dish</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: dish → ___",
    "dishes"
)

display(HTML('<h3>Exercise 11</h3>'))
display(HTML('<p><strong>Singular:</strong> watch</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: watch → ___",
    "watches"
)

display(HTML('<h3>Exercise 12</h3>'))
display(HTML('<p><strong>Singular:</strong> class</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: class → ___",
    "classes"
)

display(HTML('<h3>Exercise 13</h3>'))
display(HTML('<p><strong>Singular:</strong> brush</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: brush → ___",
    "brushes"
)

display(HTML('<h3>Exercise 14</h3>'))
display(HTML('<p>She has three ___ (sandwich).</p>'))
exercise.create_fill_in_blank(
    "Answer: She has three ___ (sandwich).",
    "sandwiches"
)

print("\n✅ Exercise Set 2 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 3: Consonant + Y → IES 🎈
#
# **Rule**: When a noun ends in **consonant + y**, change **y** to **ies**.
#
# **Example**: city → cities, baby → babies
#
# Write the plural form.
#
# ---

# %%
# Exercise Set 3: Consonant + Y → IES

display(HTML('<h3>Exercise 15</h3>'))
display(HTML('<p><strong>Singular:</strong> city</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: city → ___",
    "cities"
)

display(HTML('<h3>Exercise 16</h3>'))
display(HTML('<p><strong>Singular:</strong> baby</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: baby → ___",
    "babies"
)

display(HTML('<h3>Exercise 17</h3>'))
display(HTML('<p><strong>Singular:</strong> country</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: country → ___",
    "countries"
)

display(HTML('<h3>Exercise 18</h3>'))
display(HTML('<p><strong>Singular:</strong> party</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: party → ___",
    "parties"
)

display(HTML('<h3>Exercise 19</h3>'))
display(HTML('<p><strong>Singular:</strong> lady</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: lady → ___",
    "ladies"
)

display(HTML('<h3>Exercise 20</h3>'))
display(HTML('<p>I visited three ___ (country) last year.</p>'))
exercise.create_fill_in_blank(
    "Answer: I visited three ___ (country) last year.",
    "countries"
)

print("\n✅ Exercise Set 3 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 4: Vowel + Y → YS 🔑
#
# **Rule**: When a noun ends in **vowel + y**, just add **-s** (don't change the y).
#
# **Example**: boy → boys, day → days
#
# Write the plural form.
#
# ---

# %%
# Exercise Set 4: Vowel + Y → YS

display(HTML('<h3>Exercise 21</h3>'))
display(HTML('<p><strong>Singular:</strong> boy</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: boy → ___",
    "boys"
)

display(HTML('<h3>Exercise 22</h3>'))
display(HTML('<p><strong>Singular:</strong> day</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: day → ___",
    "days"
)

display(HTML('<h3>Exercise 23</h3>'))
display(HTML('<p><strong>Singular:</strong> key</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: key → ___",
    "keys"
)

display(HTML('<h3>Exercise 24</h3>'))
display(HTML('<p><strong>Singular:</strong> toy</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: toy → ___",
    "toys"
)

display(HTML('<h3>Exercise 25</h3>'))
display(HTML('<p>There are seven ___ (day) in a week.</p>'))
exercise.create_fill_in_blank(
    "Answer: There are seven ___ (day) in a week.",
    "days"
)

print("\n✅ Exercise Set 4 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 5: F/FE → VES 🍂
#
# **Rule**: For many nouns ending in **-f** or **-fe**, change to **-ves**.
#
# **Example**: knife → knives, leaf → leaves
#
# Write the plural form.
#
# ---

# %%
# Exercise Set 5: F/FE → VES

display(HTML('<h3>Exercise 26</h3>'))
display(HTML('<p><strong>Singular:</strong> knife</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: knife → ___",
    "knives"
)

display(HTML('<h3>Exercise 27</h3>'))
display(HTML('<p><strong>Singular:</strong> leaf</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: leaf → ___",
    "leaves"
)

display(HTML('<h3>Exercise 28</h3>'))
display(HTML('<p><strong>Singular:</strong> life</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: life → ___",
    "lives"
)

display(HTML('<h3>Exercise 29</h3>'))
display(HTML('<p><strong>Singular:</strong> wife</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: wife → ___",
    "wives"
)

display(HTML('<h3>Exercise 30</h3>'))
display(HTML('<p><strong>Singular:</strong> shelf</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: shelf → ___",
    "shelves"
)

display(HTML('<h3>Exercise 31</h3>'))
display(HTML('<p>The ___ (leaf) fall in autumn.</p>'))
exercise.create_fill_in_blank(
    "Answer: The ___ (leaf) fall in autumn.",
    "leaves"
)

print("\n✅ Exercise Set 5 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 6: Irregular Plurals 🦌
#
# **Rule**: These plurals don't follow regular patterns. You must **memorize** them!
#
# **Examples**: man → men, child → children, foot → feet
#
# Write the plural form.
#
# ---

# %%
# Exercise Set 6: Irregular Plurals

display(HTML('<h3>Exercise 32</h3>'))
display(HTML('<p><strong>Singular:</strong> man</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: man → ___",
    "men"
)

display(HTML('<h3>Exercise 33</h3>'))
display(HTML('<p><strong>Singular:</strong> woman</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: woman → ___",
    "women"
)

display(HTML('<h3>Exercise 34</h3>'))
display(HTML('<p><strong>Singular:</strong> child</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: child → ___",
    "children"
)

display(HTML('<h3>Exercise 35</h3>'))
display(HTML('<p><strong>Singular:</strong> person</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: person → ___",
    "people"
)

display(HTML('<h3>Exercise 36</h3>'))
display(HTML('<p><strong>Singular:</strong> foot</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: foot → ___",
    "feet"
)

display(HTML('<h3>Exercise 37</h3>'))
display(HTML('<p><strong>Singular:</strong> tooth</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: tooth → ___",
    "teeth"
)

display(HTML('<h3>Exercise 38</h3>'))
display(HTML('<p><strong>Singular:</strong> mouse</p>'))
display(HTML('<p><strong>Plural:</strong> ___</p>'))
exercise.create_fill_in_blank(
    "Answer: mouse → ___",
    "mice"
)

display(HTML('<h3>Exercise 39</h3>'))
display(HTML('<p>Many ___ (person) visit this museum.</p>'))
exercise.create_fill_in_blank(
    "Answer: Many ___ (person) visit this museum.",
    "people"
)

print("\n✅ Exercise Set 6 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 7: Same-Form Plurals 🐑
#
# **Rule**: These nouns have the **same form** in singular and plural.
#
# **Examples**: sheep → sheep, deer → deer, fish → fish
#
# Complete the sentences.
#
# ---

# %%
# Exercise Set 7: Same-Form Plurals

display(HTML('<h3>Exercise 40</h3>'))
display(HTML('<p>One sheep, two ___ (same form).</p>'))
exercise.create_fill_in_blank(
    "Answer: One sheep, two ___.",
    "sheep"
)

display(HTML('<h3>Exercise 41</h3>'))
display(HTML('<p>One deer, three ___ (same form).</p>'))
exercise.create_fill_in_blank(
    "Answer: One deer, three ___.",
    "deer"
)

display(HTML('<h3>Exercise 42</h3>'))
display(HTML('<p>One fish, many ___ (same form).</p>'))
exercise.create_fill_in_blank(
    "Answer: One fish, many ___.",
    "fish"
)

display(HTML('<h3>Exercise 43</h3>'))
display(HTML('<p>The farmer has ten ___ (sheep).</p>'))
exercise.create_fill_in_blank(
    "Answer: The farmer has ten ___ (sheep).",
    "sheep"
)

display(HTML('<h3>Exercise 44</h3>'))
display(HTML('<p>I saw two ___ (deer) in the forest.</p>'))
exercise.create_fill_in_blank(
    "Answer: I saw two ___ (deer) in the forest.",
    "deer"
)

print("\n✅ Exercise Set 7 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 8: Countable vs Uncountable 💧
#
# **Rule**:
# - **Countable** nouns have plurals (book → books)
# - **Uncountable** nouns have NO plural (water, advice, information)
#
# Choose the correct form.
#
# ---

# %%
# Exercise Set 8: Countable vs Uncountable

display(HTML('<h3>Exercise 45</h3>'))
display(HTML('<p>I drink ___ every day. (water / waters)</p>'))
exercise.create_multiple_choice(
    "Choose: I drink ___ every day.",
    ["water", "waters"],
    "water"
)

display(HTML('<h3>Exercise 46</h3>'))
display(HTML('<p>She needs some ___. (information / informations)</p>'))
exercise.create_multiple_choice(
    "Choose: She needs some ___.",
    ["information", "informations"],
    "information"
)

display(HTML('<h3>Exercise 47</h3>'))
display(HTML('<p>He gave me good ___. (advice / advices)</p>'))
exercise.create_multiple_choice(
    "Choose: He gave me good ___.",
    ["advice", "advices"],
    "advice"
)

display(HTML('<h3>Exercise 48</h3>'))
display(HTML('<p>I have a lot of ___. (homework / homeworks)</p>'))
exercise.create_multiple_choice(
    "Choose: I have a lot of ___.",
    ["homework", "homeworks"],
    "homework"
)

display(HTML('<h3>Exercise 49</h3>'))
display(HTML('<p>There is new ___ in the living room. (furniture / furnitures)</p>'))
exercise.create_multiple_choice(
    "Choose: There is new ___ in the living room.",
    ["furniture", "furnitures"],
    "furniture"
)

display(HTML('<h3>Exercise 50</h3>'))
display(HTML('<p>I need ___ of water. (a glass / a water)</p>'))
exercise.create_multiple_choice(
    "Choose: I need ___ of water.",
    ["a glass", "a water"],
    "a glass"
)

display(HTML('<h3>Exercise 51</h3>'))
display(HTML('<p>Can I have ___? (a bread / a slice of bread)</p>'))
exercise.create_multiple_choice(
    "Choose: Can I have ___?",
    ["a bread", "a slice of bread"],
    "a slice of bread"
)

print("\n✅ Exercise Set 8 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 9: Mixed Practice 🔄
#
# **Challenge**: Mix of all plural rules! Think carefully about which rule to apply.
#
# Write the correct plural form.
#
# ---

# %%
# Exercise Set 9: Mixed Practice

display(HTML('<h3>Exercise 52</h3>'))
display(HTML('<p>I have three ___ (apple).</p>'))
exercise.create_fill_in_blank(
    "Answer: I have three ___ (apple).",
    "apples"
)

display(HTML('<h3>Exercise 53</h3>'))
display(HTML('<p>There are many ___ (church) in this city.</p>'))
exercise.create_fill_in_blank(
    "Answer: There are many ___ (church) in this city.",
    "churches"
)

display(HTML('<h3>Exercise 54</h3>'))
display(HTML('<p>The ___ (woman) are doctors.</p>'))
exercise.create_fill_in_blank(
    "Answer: The ___ (woman) are doctors.",
    "women"
)

display(HTML('<h3>Exercise 55</h3>'))
display(HTML('<p>She reads interesting ___ (story).</p>'))
exercise.create_fill_in_blank(
    "Answer: She reads interesting ___ (story).",
    "stories"
)

display(HTML('<h3>Exercise 56</h3>'))
display(HTML('<p>I need two ___ (tomato) for the salad.</p>'))
exercise.create_fill_in_blank(
    "Answer: I need two ___ (tomato) for the salad.",
    "tomatoes"
)

display(HTML('<h3>Exercise 57</h3>'))
display(HTML('<p>The ___ (child) play in the park.</p>'))
exercise.create_fill_in_blank(
    "Answer: The ___ (child) play in the park.",
    "children"
)

display(HTML('<h3>Exercise 58</h3>'))
display(HTML('<p>All the ___ (family) live on this street.</p>'))
exercise.create_fill_in_blank(
    "Answer: All the ___ (family) live on this street.",
    "families"
)

display(HTML('<h3>Exercise 59</h3>'))
display(HTML('<p>My ___ (foot) hurt after the long walk.</p>'))
exercise.create_fill_in_blank(
    "Answer: My ___ (foot) hurt after the long walk.",
    "feet"
)

print("\n✅ Exercise Set 9 complete!")

# %% [markdown]
# ---
#
# ## Exercise Set 10: Error Correction ⚠️
#
# **Task**: Find and correct the plural errors in these sentences.
#
# Write the correct form.
#
# ---

# %%
# Exercise Set 10: Error Correction

display(HTML('<h3>Exercise 60</h3>'))
display(HTML('<p>❌ I have two boxs.</p>'))
display(HTML('<p>✅ Correct form: I have two ___.</p>'))
exercise.create_fill_in_blank(
    "Answer: I have two ___.",
    "boxes"
)

display(HTML('<h3>Exercise 61</h3>'))
display(HTML('<p>❌ There are three childs.</p>'))
display(HTML('<p>✅ Correct form: There are three ___.</p>'))
exercise.create_fill_in_blank(
    "Answer: There are three ___.",
    "children"
)

display(HTML('<h3>Exercise 62</h3>'))
display(HTML('<p>❌ I visited two citys.</p>'))
display(HTML('<p>✅ Correct form: I visited two ___.</p>'))
exercise.create_fill_in_blank(
    "Answer: I visited two ___.",
    "cities"
)

display(HTML('<h3>Exercise 63</h3>'))
display(HTML('<p>❌ I need many informations.</p>'))
display(HTML('<p>✅ Correct form: I need much ___.</p>'))
exercise.create_fill_in_blank(
    "Answer: I need much ___.",
    "information"
)

display(HTML('<h3>Exercise 64</h3>'))
display(HTML('<p>❌ The mans are tall.</p>'))
display(HTML('<p>✅ Correct form: The ___ are tall.</p>'))
exercise.create_fill_in_blank(
    "Answer: The ___ are tall.",
    "men"
)

display(HTML('<h3>Exercise 65</h3>'))
display(HTML('<p>❌ I saw two deers.</p>'))
display(HTML('<p>✅ Correct form: I saw two ___.</p>'))
exercise.create_fill_in_blank(
    "Answer: I saw two ___.",
    "deer"
)

print("\n✅ Exercise Set 10 complete!")

# %% [markdown]
# ---
#
# ## 📊 Your Final Score
#
# ---

# %%
# Display your final score
validator.display_score()

print("\n" + "="*50)
print("🎉 CONGRATULATIONS!")
print("="*50)
print("\nYou've completed all 65 exercises on plural formation!")
print("\n📚 What you practiced:")
print("  ✅ Regular plurals (add -s)")
print("  ✅ Plurals with -es")
print("  ✅ Consonant + y → ies")
print("  ✅ Vowel + y → ys")
print("  ✅ F/FE → ves")
print("  ✅ Irregular plurals")
print("  ✅ Same-form plurals")
print("  ✅ Countable vs uncountable")
print("  ✅ Mixed practice")
print("  ✅ Error correction")
print("\n💡 Remember: Most plurals just add -s!")
print("   But watch out for the special cases!")

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# Great work on completing the controlled practice!
#
# ### Continue to:
# 📝 **03_meaningful_practice.ipynb** for personalized activities using plural nouns!
#
# ### In the next notebook, you'll:
# - ✅ Describe your possessions using plurals
# - ✅ Write about things in your home
# - ✅ Talk about people you know
# - ✅ Create shopping lists
# - ✅ Use plurals in your real life context
#
# **See you in the next notebook!** 🚀
#
# ---
