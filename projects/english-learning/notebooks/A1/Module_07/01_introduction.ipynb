# %% [markdown]
# # Module 07: Possessives - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **Possessive Adjectives and 's**
#
# ### Learning Objectives
#
# - Possessive adjectives (my, your, his, her, its, our, their)
# - Possessive 's (John's book)
# - Possessive with plural nouns (the students' books)
# - Whose...? questions
# - Its vs It's distinction
#
# ### Time Requirement
# ⏱️ Estimated time: 5-7 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Learn to show possession using possessive adjectives and possessive 's
#
# ---
#
# ## Key Concepts
#
# - Possessive adjectives (my, your, his, her, its, our, their)
# - Possessive 's (John's book)
# - Possessive with plural nouns (the students' books)
# - Whose...? questions
# - Its vs It's distinction
#
# ---
#
# ## Examples
#
# ### Example 1: This is my book.
# **Possessive adjective**
#
# ### Example 2: That's John's car.
# **Possessive 's**
#
# ### Example 3: Her name is Sarah.
# **Possessive adjective**
#
# ### Example 4: The teachers' room
# **Plural possessive**
#
# ### Example 5: Whose pen is this?
# **Question**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
