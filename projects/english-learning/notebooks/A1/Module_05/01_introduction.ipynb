# %% [markdown]
# # Module 05: Articles and Demonstratives - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **A/An, The, This/That/These/Those**
#
# ### Learning Objectives
#
# - A vs An (a book, an apple)
# - When to use 'the'
# - This/that for singular (near/far)
# - These/those for plural (near/far)
# - Zero article (no article needed)
#
# ### Time Requirement
# ⏱️ Estimated time: 6-8 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Master the use of indefinite articles (a/an), definite article (the), and demonstratives
#
# ---
#
# ## Key Concepts
#
# - A vs An (a book, an apple)
# - When to use 'the'
# - This/that for singular (near/far)
# - These/those for plural (near/far)
# - Zero article (no article needed)
#
# ---
#
# ## Examples
#
# ### Example 1: I have a car.
# **Indefinite article a**
#
# ### Example 2: She eats an orange.
# **Indefinite article an**
#
# ### Example 3: The sun is bright.
# **Definite article**
#
# ### Example 4: This book is interesting.
# **Near singular**
#
# ### Example 5: Those trees are tall.
# **Far plural**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
