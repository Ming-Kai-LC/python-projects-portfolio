# %% [markdown]
# # Module 08: Adjectives - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **Describing People, Places, and Things**
#
# ### Learning Objectives
#
# - Adjectives before nouns (a big house)
# - Adjectives after 'be' (She is happy)
# - Common opposites (big/small, hot/cold)
# - Color adjectives
# - Basic adjective order
#
# ### Time Requirement
# ⏱️ Estimated time: 5-7 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Learn to use adjectives before nouns and after 'be' to describe things
#
# ---
#
# ## Key Concepts
#
# - Adjectives before nouns (a big house)
# - Adjectives after 'be' (She is happy)
# - Common opposites (big/small, hot/cold)
# - Color adjectives
# - Basic adjective order
#
# ---
#
# ## Examples
#
# ### Example 1: A beautiful garden
# **Adjective before noun**
#
# ### Example 2: The car is red.
# **Adjective after 'be'**
#
# ### Example 3: She is tall.
# **Describing person**
#
# ### Example 4: It's a cold day.
# **Describing weather**
#
# ### Example 5: They are happy.
# **Describing feeling**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
