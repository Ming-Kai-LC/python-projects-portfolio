# %% [markdown]
# # Module 2: Personal Pronouns - Controlled Practice
#
# ## 📝 Phase 2: Controlled Practice (20% of learning time)
#
# Welcome to the practice phase! Here you'll complete exercises with **immediate feedback** to build accuracy.
#
# ### What You'll Do:
# - ✅ Choose correct subject pronouns
# - ✅ Choose correct object pronouns
# - ✅ Replace names with pronouns
# - ✅ Correct pronoun errors
# - ✅ Complete conversations
#
# ⏱️ **Estimated time:** 90-120 minutes
#
# ---

# %%
# Setup
import sys
sys.path.append('../../../utils')

from feedback_system import ExerciseValidator, InteractiveExercise, create_progress_bar
from IPython.display import display, HTML

# Initialize validator and exercise system
validator = ExerciseValidator()
exercise = InteractiveExercise(validator)

print("✅ Ready to practice! Complete all exercises below.")

# %% [markdown]
# ---
#
# ## Exercise Set 1: Subject Pronouns
#
# Complete each sentence with the correct subject pronoun.
#
# ### Instructions:
# Type the correct pronoun (I, you, he, she, it, we, they)
#
# ---

# %%
# Exercise 1.1
exercise.create_fill_in_blank(
    "1. (My sister) ___ is a teacher.",
    "She"
)

# %%
# Exercise 1.2
exercise.create_fill_in_blank(
    "2. (John) ___ works in a bank.",
    "He"
)

# %%
# Exercise 1.3
exercise.create_fill_in_blank(
    "3. (My friends and I) ___ are students.",
    "We"
)

# %%
# Exercise 1.4
exercise.create_fill_in_blank(
    "4. (The dog) ___ is very cute.",
    "It"
)

# %%
# Exercise 1.5
exercise.create_fill_in_blank(
    "5. (Tom and Sarah) ___ are married.",
    "They"
)

# %%
# Exercise 1.6
exercise.create_fill_in_blank(
    "6. (My mother) ___ loves cooking.",
    "She"
)

# %%
# Exercise 1.7
exercise.create_fill_in_blank(
    "7. (The book) ___ is on the table.",
    "It"
)

# %%
# Exercise 1.8
exercise.create_fill_in_blank(
    "8. (You and your brother) ___ are very tall.",
    "You"
)

# %%
# Exercise 1.9
exercise.create_fill_in_blank(
    "9. (My father) ___ is a doctor.",
    "He"
)

# %%
# Exercise 1.10
exercise.create_fill_in_blank(
    "10. (The students) ___ are in the classroom.",
    "They"
)

# %% [markdown]
# ---
#
# ## Exercise Set 2: Object Pronouns
#
# Complete with the correct object pronoun (me, you, him, her, it, us, them).
#
# ---

# %%
# Exercise 2.1
exercise.create_fill_in_blank(
    "1. I know (John). I know ___.",
    "him"
)

# %%
# Exercise 2.2
exercise.create_fill_in_blank(
    "2. Call (Maria) tomorrow. Call ___ tomorrow.",
    "her"
)

# %%
# Exercise 2.3
exercise.create_fill_in_blank(
    "3. Give (the book) to me. Give ___ to me.",
    "it"
)

# %%
# Exercise 2.4
exercise.create_fill_in_blank(
    "4. She loves (me and my brother). She loves ___.",
    "us"
)

# %%
# Exercise 2.5
exercise.create_fill_in_blank(
    "5. I see (Tom and Sarah). I see ___.",
    "them"
)

# %%
# Exercise 2.6
exercise.create_fill_in_blank(
    "6. They help (my friend). They help ___.",
    "her"
)

# %%
# Exercise 2.7
exercise.create_fill_in_blank(
    "7. Listen to (your teacher). Listen to ___.",
    "him"
)

# %%
# Exercise 2.8
exercise.create_fill_in_blank(
    "8. My parents love (me). My parents love ___.",
    "me"
)

# %% [markdown]
# ---
#
# ## Exercise Set 3: Multiple Choice - Subject or Object?
#
# Choose the correct pronoun.
#
# ---

# %%
# Exercise 3.1
exercise.create_multiple_choice(
    "___ is my friend.",
    {"A": "He", "B": "Him"},
    "A",
    "Use 'He' as subject pronoun before the verb."
)

# %%
# Exercise 3.2
exercise.create_multiple_choice(
    "I know ___.",
    {"A": "she", "B": "her"},
    "B",
    "Use 'her' as object pronoun after the verb 'know'."
)

# %%
# Exercise 3.3
exercise.create_multiple_choice(
    "___ are students.",
    {"A": "They", "B": "Them"},
    "A",
    "Use 'They' as subject pronoun before 'are'."
)

# %%
# Exercise 3.4
exercise.create_multiple_choice(
    "Come with ___.",
    {"A": "I", "B": "me"},
    "B",
    "After preposition 'with', use object pronoun 'me'."
)

# %%
# Exercise 3.5
exercise.create_multiple_choice(
    "___ loves chocolate.",
    {"A": "She", "B": "Her"},
    "A",
    "Use 'She' as subject pronoun before verb 'loves'."
)

# %%
# Exercise 3.6
exercise.create_multiple_choice(
    "Give it to ___.",
    {"A": "they", "B": "them"},
    "B",
    "After preposition 'to', use object pronoun 'them'."
)

# %%
# Exercise 3.7
exercise.create_multiple_choice(
    "___ are happy.",
    {"A": "We", "B": "Us"},
    "A",
    "Use 'We' as subject pronoun before 'are'."
)

# %%
# Exercise 3.8
exercise.create_multiple_choice(
    "My teacher helps ___.",
    {"A": "we", "B": "us"},
    "B",
    "After verb 'helps', use object pronoun 'us'."
)

# %% [markdown]
# ---
#
# ## Exercise Set 4: Error Correction
#
# Find and correct the pronoun error in each sentence.
#
# ---

# %%
# Exercise 4.1
display(HTML('<p><strong>Incorrect:</strong> <u>Me</u> am a student.</p>'))
exercise.create_fill_in_blank(
    "Corrected: ___ am a student.",
    "I"
)

# %%
# Exercise 4.2
display(HTML('<p><strong>Incorrect:</strong> <u>Him</u> is my friend.</p>'))
exercise.create_fill_in_blank(
    "Corrected: ___ is my friend.",
    "He"
)

# %%
# Exercise 4.3
display(HTML('<p><strong>Incorrect:</strong> I know <u>she</u>.</p>'))
exercise.create_fill_in_blank(
    "Corrected: I know ___.",
    "her"
)

# %%
# Exercise 4.4
display(HTML('<p><strong>Incorrect:</strong> Come with <u>I</u>.</p>'))
exercise.create_fill_in_blank(
    "Corrected: Come with ___.",
    "me"
)

# %%
# Exercise 4.5
display(HTML('<p><strong>Incorrect:</strong> <u>Them</u> are busy.</p>'))
exercise.create_fill_in_blank(
    "Corrected: ___ are busy.",
    "They"
)

# %%
# Exercise 4.6
display(HTML('<p><strong>Incorrect:</strong> Give it to <u>they</u>.</p>'))
exercise.create_fill_in_blank(
    "Corrected: Give it to ___.",
    "them"
)

# %%
# Exercise 4.7
display(HTML('<p><strong>Incorrect:</strong> <u>Us</u> are students.</p>'))
exercise.create_fill_in_blank(
    "Corrected: ___ are students.",
    "We"
)

# %%
# Exercise 4.8
display(HTML('<p><strong>Incorrect:</strong> My teacher helps <u>we</u>.</p>'))
exercise.create_fill_in_blank(
    "Corrected: My teacher helps ___.",
    "us"
)

# %% [markdown]
# ---
#
# ## Exercise Set 5: Complete the Conversation
#
# Fill in the missing pronouns in these dialogues.
#
# ---

# %%
# Exercise 5.1
display(HTML('<p><strong>A:</strong> Is Maria your sister?</p>'))
exercise.create_fill_in_blank(
    "B: Yes, ___ is.",
    "she"
)

# %%
# Exercise 5.2
display(HTML('<p><strong>A:</strong> Do you know John?</p>'))
exercise.create_fill_in_blank(
    "B: Yes, I know ___.",
    "him"
)

# %%
# Exercise 5.3
display(HTML('<p><strong>A:</strong> Are your parents at home?</p>'))
exercise.create_fill_in_blank(
    "B: Yes, ___ are.",
    "they"
)

# %%
# Exercise 5.4
display(HTML('<p><strong>A:</strong> Can you help my brother and me?</p>'))
exercise.create_fill_in_blank(
    "B: Of course! I can help ___.",
    "you"
)

# %%
# Exercise 5.5
display(HTML('<p><strong>A:</strong> Where is the book?</p>'))
exercise.create_fill_in_blank(
    "B: ___ is on the table.",
    "It"
)

# %% [markdown]
# ---
#
# ## Exercise Set 6: Mixed Practice
#
# Complete these sentences with the correct pronoun (subject or object).
#
# ---

# %%
# Exercise 6.1
exercise.create_fill_in_blank(
    "1. My sister and I are friends. ___ are very close.",
    "We"
)

# %%
# Exercise 6.2
exercise.create_fill_in_blank(
    "2. I have a dog. I love ___ very much.",
    "it"
)

# %%
# Exercise 6.3
exercise.create_fill_in_blank(
    "3. Tom is my friend. ___ lives near my house.",
    "He"
)

# %%
# Exercise 6.4
exercise.create_fill_in_blank(
    "4. I see Maria every day. I see ___ at school.",
    "her"
)

# %%
# Exercise 6.5
exercise.create_fill_in_blank(
    "5. My parents are doctors. ___ work in a hospital.",
    "They"
)

# %%
# Exercise 6.6
exercise.create_fill_in_blank(
    "6. Can you call ___? (me)",
    "me"
)

# %%
# Exercise 6.7
exercise.create_fill_in_blank(
    "7. The children are playing. Watch ___!",
    "them"
)

# %% [markdown]
# ---
#
# ## 📊 Your Score

# %%
# Display final score
validator.display_score()

# %% [markdown]
# ---
#
# ## 🎯 What's Next?
#
# ### If your score is:
# - **80%+**: Excellent! Move to **03_meaningful_practice.ipynb** ✅
# - **60-79%**: Good progress! Review mistakes, then continue to next phase 👍
# - **Below 60%**: Review **01_introduction.ipynb** and retry these exercises 📚
#
# ---
#
# ### Continue to:
# **03_meaningful_practice.ipynb** - Use pronouns with your own information!
#
# ---
#
# **Great work!** 🌟 You've completed the controlled practice phase!
