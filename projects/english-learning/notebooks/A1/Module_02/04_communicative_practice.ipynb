# %% [markdown]
# # Module 02: Personal Pronouns - Communicative Practice
#
# ## 💬 Phase 4: Communicative Practice (30% of learning time)
#
# Use personal pronouns in real communication!
#
# ⏱️ **Estimated time:** 2-3 hours
#
# ---

# %%
# Setup
import sys
sys.path.append('../../../utils')

from spaced_repetition import SpacedRepetitionScheduler
scheduler = SpacedRepetitionScheduler(data_file="../../../data/progress.json")
print("✅ Ready for communication!")

# %% [markdown]
# ## Task 1: Role-Play
#
# Practice real conversations using this grammar.
#
# **Double-click to write!**
#
# ---

# %% [markdown]
# ## Task 2: Creative Writing
#
# Write a story or description using the grammar.
#
# ---

# %%
# Mark module complete (uncomment when finished)
# scheduler.mark_module_complete(
#     module_id="A1_Module_02",
#     module_name="Personal Pronouns",
#     score=85.0
# )

# %% [markdown]
# ## 🎯 Module Complete!
#
# Great job! You've finished Module 02: Personal Pronouns
#
# Continue to the next module!
#
# ---
