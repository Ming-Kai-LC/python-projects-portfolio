# %% [markdown]
# # Module 04: Present Simple - Negatives and Questions - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **Using Do/Does for Questions and Negatives**
#
# ### Learning Objectives
#
# - Negatives with don't/doesn't
# - Questions with Do/Does
# - Word order in questions
# - Short answers (Yes, I do / No, I don't)
# - Wh-questions (What do you...?)
#
# ### Time Requirement
# ⏱️ Estimated time: 8-10 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Learn to form negative sentences and questions in Present Simple using do/does
#
# ---
#
# ## Key Concepts
#
# - Negatives with don't/doesn't
# - Questions with Do/Does
# - Word order in questions
# - Short answers (Yes, I do / No, I don't)
# - Wh-questions (What do you...?)
#
# ---
#
# ## Examples
#
# ### Example 1: I don't like coffee.
# **Negative with don't**
#
# ### Example 2: She doesn't work here.
# **Negative with doesn't**
#
# ### Example 3: Do you speak English?
# **Yes/No question**
#
# ### Example 4: Does he live in Tokyo?
# **Third person question**
#
# ### Example 5: Where do they work?
# **Wh-question**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
