# %% [markdown]
# # Module 09: There Is / There Are - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **Expressing Existence and Location**
#
# ### Learning Objectives
#
# - There is for singular
# - There are for plural
# - Questions: Is there...? / Are there...?
# - Negatives: There isn't / There aren't
# - Using with prepositions of place
#
# ### Time Requirement
# ⏱️ Estimated time: 5-7 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Learn to use 'there is' and 'there are' to talk about existence and location
#
# ---
#
# ## Key Concepts
#
# - There is for singular
# - There are for plural
# - Questions: Is there...? / Are there...?
# - Negatives: There isn't / There aren't
# - Using with prepositions of place
#
# ---
#
# ## Examples
#
# ### Example 1: There is a book on the table.
# **Singular**
#
# ### Example 2: There are three chairs.
# **Plural**
#
# ### Example 3: Is there a bank nearby?
# **Question**
#
# ### Example 4: There aren't any apples.
# **Negative**
#
# ### Example 5: There's a cat under the bed.
# **With preposition**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
