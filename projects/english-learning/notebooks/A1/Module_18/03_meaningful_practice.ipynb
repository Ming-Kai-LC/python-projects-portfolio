# %% [markdown]
# # Module 18: Going To Future - Phase 3: Meaningful Practice
#
# ## Overview
# 10 meaningful activities
#
# **Activities:**
# 1. My Future Plans
# 2. Weekend Plans
# 3. Making Predictions
# 4. Travel Plans
# 5. Life Goals
# 6. Weather Predictions
# 7. Career Plans
# 8. Family Activities
# 9. Event Planning
# 10. New Year Resolutions

# %% [markdown]
# ## Activity 1: My Future Plans
#
# Write about your my future plans using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 1: My Future Plans
print("My Future Plans")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 2: Weekend Plans
#
# Write about your weekend plans using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 2: Weekend Plans
print("Weekend Plans")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 3: Making Predictions
#
# Write about your making predictions using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 3: Making Predictions
print("Making Predictions")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 4: Travel Plans
#
# Write about your travel plans using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 4: Travel Plans
print("Travel Plans")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 5: Life Goals
#
# Write about your life goals using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 5: Life Goals
print("Life Goals")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 6: Weather Predictions
#
# Write about your weather predictions using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 6: Weather Predictions
print("Weather Predictions")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 7: Career Plans
#
# Write about your career plans using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 7: Career Plans
print("Career Plans")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 8: Family Activities
#
# Write about your family activities using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 8: Family Activities
print("Family Activities")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 9: Event Planning
#
# Write about your event planning using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 9: Event Planning
print("Event Planning")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")

# %% [markdown]
# ## Activity 10: New Year Resolutions
#
# Write about your new year resolutions using "going to".
#
# **Instructions:**
# 1. Write 8-10 sentences
# 2. Use different forms (affirmative, negative, questions)
# 3. Include time expressions
# 4. Be specific and personal
#
# **Example:**
# I'm going to [complete this activity]...

# %%
# Activity 10: New Year Resolutions
print("New Year Resolutions")
print("=" * 60)
print("\nWrite your plans using 'going to':")
print()

for j in range(1, 9):
    print(f"{j}. I'm going to __________________________")

print("\nShare your answers with a partner!")
