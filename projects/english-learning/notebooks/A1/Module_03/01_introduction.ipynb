# %% [markdown]
# # Module 03: Present Simple - Affirmative - Introduction
#
# ## 📚 Phase 1: Introduction (15% of learning time)
#
# **Positive Statements and Third-Person -s**
#
# ### Learning Objectives
#
# - Present Simple formation for all persons
# - Third-person -s (he/she/it walks)
# - Spelling rules for -s/-es/-ies
# - When to use Present Simple (habits, facts, routines)
# - Adverbs of frequency with Present Simple
#
# ### Time Requirement
# ⏱️ Estimated time: 10-15 hours
#
# ---

# %%
# Setup: Import utilities
import sys
sys.path.append('../../../utils')

from audio_generator import AudioGenerator, create_pronunciation_guide
from IPython.display import display, HTML

audio = AudioGenerator(audio_dir="audio")
print("✅ Setup complete!")

# %% [markdown]
# ## What You'll Learn
#
# Learn to form positive statements in Present Simple tense, with special focus on third-person -s
#
# ---
#
# ## Key Concepts
#
# - Present Simple formation for all persons
# - Third-person -s (he/she/it walks)
# - Spelling rules for -s/-es/-ies
# - When to use Present Simple (habits, facts, routines)
# - Adverbs of frequency with Present Simple
#
# ---
#
# ## Examples
#
# ### Example 1: I work in an office.
# **First person**
#
# ### Example 2: You play football.
# **Second person**
#
# ### Example 3: He walks to school.
# **Third person -s**
#
# ### Example 4: She studies English.
# **Third person -ies**
#
# ### Example 5: They live in Paris.
# **Plural**
#
# ---

# %% [markdown]
# ## 🎯 What's Next?
#
# Continue to **02_controlled_practice.ipynb** for exercises!
#
# ---
