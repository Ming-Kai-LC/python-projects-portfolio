# %% [markdown]
# # A2 Module 25: A2 Consolidation and Review - Integration and Real-World Communication
# ## Phase 2: Controlled Practice
#
# **Total Exercises:** 99
# **Focus:** Integration
#
# ---
#
# ## Welcome to Controlled Practice!
#
# In this phase, you'll complete 99 structured exercises to build automaticity with integration.
#
# ### How to Use This Notebook
#
# 1. Read each exercise carefully
# 2. Write your answer
# 3. Check the feedback immediately
# 4. Review mistakes and try again
# 5. Track your progress
#
# ### Exercise Structure
#
# This notebook contains 10 exercise sets covering:
# - Formation and structure
# - Usage in context
# - Common error correction
# - Sentence transformation
# - Integration with previous grammar
#
# **Let's begin!**
#
# ---

# %%
# Setup: Import feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

print("[OK] Feedback system loaded successfully!")
print("You're ready to start the exercises.\n")

# %% [markdown]
# ### Exercise Set 1: Formation Basics
#
# **Exercises:** 9
# **Focus:** Basic integration formation
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 1: Formation Basics

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 9 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 2: Usage Practice
#
# **Exercises:** 9
# **Focus:** Apply rules in different contexts
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 2: Usage Practice

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 9 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 3: Gap Filling
#
# **Exercises:** 8
# **Focus:** Complete sentences with correct forms
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 3: Gap Filling

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 8 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 4: Sentence Building
#
# **Exercises:** 8
# **Focus:** Construct full sentences
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 4: Sentence Building

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 8 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 5: Error Correction
#
# **Exercises:** 10
# **Focus:** Identify and fix mistakes
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 5: Error Correction

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 10 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 6: Transformation
#
# **Exercises:** 8
# **Focus:** Transform sentence structures
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 6: Transformation

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 8 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 7: Context Selection
#
# **Exercises:** 8
# **Focus:** Choose appropriate forms for context
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 7: Context Selection

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 8 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 8: Integration Practice
#
# **Exercises:** 10
# **Focus:** Combine with previous grammar
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 8: Integration Practice

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 10 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 9: Question Formation
#
# **Exercises:** 8
# **Focus:** Create questions
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 9: Question Formation

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 8 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ### Exercise Set 10: Mixed Practice
#
# **Exercises:** 18
# **Focus:** Comprehensive practice
#
# Complete the following exercises. Check your answers after each one.

# %%
# Exercise Set 10: Mixed Practice

# Import the feedback system
import sys
sys.path.append('../../..')
from utils.feedback_system import ExerciseValidator

# Initialize validator
validator = ExerciseValidator()

# Exercise 1
print("Exercise 1: [Exercise text to be added]")
answer_1 = input("Your answer: ")
validator.check_answer(answer_1, "correct_answer_here", "Exercise 1")

# Exercise 2
print("\nExercise 2: [Exercise text to be added]")
answer_2 = input("Your answer: ")
validator.check_answer(answer_2, "correct_answer_here", "Exercise 2")

# [Additional exercises will be added - total: 18 exercises]

# Show final score
validator.show_summary()

# %% [markdown]
# ---
#
# ## Excellent Work!
#
# You've completed Phase 2 of Module 25 - all 99 exercises!
#
# ### Next Steps
#
# Move on to **Phase 3: Meaningful Practice** where you'll create personal content using integration.
#
# ---
#
# 📚 Progress: Phase 2 of 4 complete
