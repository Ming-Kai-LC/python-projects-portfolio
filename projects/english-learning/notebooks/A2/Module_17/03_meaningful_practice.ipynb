# %% [markdown]
# # Module 17: Superlative Adjectives - The Best, The Biggest, The Most - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using superlative adjectives in real contexts

# %% [markdown]
# ## Activity 1: The Best and Worst in My Life
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 1: The Best and Worst in My Life
print("The Best and Worst in My Life")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 2: My Country's Records and Extremes
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 2: My Country's Records and Extremes
print("My Country's Records and Extremes")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 3: The Most Interesting Places I've Visited
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 3: The Most Interesting Places I've Visited
print("The Most Interesting Places I've Visited")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 4: The Best Movie/Book/Song Ever
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 4: The Best Movie/Book/Song Ever
print("The Best Movie/Book/Song Ever")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 5: My Class Superlatives
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 5: My Class Superlatives
print("My Class Superlatives")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 6: World Records Discussion
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 6: World Records Discussion
print("World Records Discussion")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 7: The Most Important Person in My Life
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 7: The Most Important Person in My Life
print("The Most Important Person in My Life")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 8: Ranking My Top 3 Favorites
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 8: Ranking My Top 3 Favorites
print("Ranking My Top 3 Favorites")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 9: The Biggest Achievements and Challenges
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 9: The Biggest Achievements and Challenges
print("The Biggest Achievements and Challenges")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 10: One of the Best Days of My Life
#
# **Comparison Focus:** superlative adjectives
#
# ### Instructions:
# 1. Write 8-10 sentences using superlative adjectives
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using superlative adjectives to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 10: One of the Best Days of My Life
print("One of the Best Days of My Life")
print("=" * 60)
print(f"\nUse superlative adjectives to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")
