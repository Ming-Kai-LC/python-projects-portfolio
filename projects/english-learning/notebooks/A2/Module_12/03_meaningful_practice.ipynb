# %% [markdown]
# # Module 12: Must/Have To - Obligation and Necessity - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using must/have to in real contexts

# %% [markdown]
# ## Activity 1: School/Work Rules and Obligations
#
# **Modal Focus:** must/have to
# **Context:** necessity
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 1: School/Work Rules and Obligations
print("School/Work Rules and Obligations")
print("=" * 60)
print(f"\nUse must/have to to talk about: necessity")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 2: Personal Responsibilities
#
# **Modal Focus:** must/have to
# **Context:** rules
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 2: Personal Responsibilities
print("Personal Responsibilities")
print("=" * 60)
print(f"\nUse must/have to to talk about: rules")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 3: Family Obligations
#
# **Modal Focus:** must/have to
# **Context:** requirements
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 3: Family Obligations
print("Family Obligations")
print("=" * 60)
print(f"\nUse must/have to to talk about: requirements")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 4: Travel Requirements
#
# **Modal Focus:** must/have to
# **Context:** obligation
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 4: Travel Requirements
print("Travel Requirements")
print("=" * 60)
print(f"\nUse must/have to to talk about: obligation")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 5: Health and Safety Must-dos
#
# **Modal Focus:** must/have to
# **Context:** necessity
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 5: Health and Safety Must-dos
print("Health and Safety Must-dos")
print("=" * 60)
print(f"\nUse must/have to to talk about: necessity")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 6: Legal Obligations in Your Country
#
# **Modal Focus:** must/have to
# **Context:** rules
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 6: Legal Obligations in Your Country
print("Legal Obligations in Your Country")
print("=" * 60)
print(f"\nUse must/have to to talk about: rules")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 7: Must vs Have to - Your Life
#
# **Modal Focus:** must/have to
# **Context:** requirements
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 7: Must vs Have to - Your Life
print("Must vs Have to - Your Life")
print("=" * 60)
print(f"\nUse must/have to to talk about: requirements")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 8: Daily Necessities
#
# **Modal Focus:** must/have to
# **Context:** obligation
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 8: Daily Necessities
print("Daily Necessities")
print("=" * 60)
print(f"\nUse must/have to to talk about: obligation")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 9: Professional Requirements
#
# **Modal Focus:** must/have to
# **Context:** necessity
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 9: Professional Requirements
print("Professional Requirements")
print("=" * 60)
print(f"\nUse must/have to to talk about: necessity")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")

# %% [markdown]
# ## Activity 10: Cultural Obligations
#
# **Modal Focus:** must/have to
# **Context:** rules
#
# ### Instructions:
# 1. Write 8-10 sentences using must/have to
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using must/have to to be added]

# %%
# Activity 10: Cultural Obligations
print("Cultural Obligations")
print("=" * 60)
print(f"\nUse must/have to to talk about: rules")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: must/have to + base verb!")
