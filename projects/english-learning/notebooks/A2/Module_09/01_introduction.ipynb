# %% [markdown]
# # Module 09: Time Sequencing (before, after, then, finally) - Phase 1: Introduction
#
# ## Learning Objectives
# - Organize events and actions in logical time order
# - Use before, after, then, next, finally to show sequence
# - Construct narratives with clear chronological flow
# - Distinguish between conjunctions and adverbs
# - Apply correct verb tenses when sequencing actions
#
# **Target Level:** A2
# **Estimated Time:** 4-5 hours

# %% [markdown]
# ## 1. Introduction and Overview
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Introduction and Overview - Practice
print("Introduction and Overview")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 2. Formation - Affirmative
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Formation - Affirmative - Practice
print("Formation - Affirmative")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 3. Formation - Negative
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Formation - Negative - Practice
print("Formation - Negative")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 4. Formation - Questions
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Formation - Questions - Practice
print("Formation - Questions")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 5. Short Answers
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Short Answers - Practice
print("Short Answers")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 6. Key Uses and Contexts
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Key Uses and Contexts - Practice
print("Key Uses and Contexts")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 7. Time Expressions
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Time Expressions - Practice
print("Time Expressions")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 8. Comparison with Other Forms
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Comparison with Other Forms - Practice
print("Comparison with Other Forms")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 9. Position and Word Order
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Position and Word Order - Practice
print("Position and Word Order")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 10. Common Collocations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Common Collocations - Practice
print("Common Collocations")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 11. Pronunciation and Contractions
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Pronunciation and Contractions - Practice
print("Pronunciation and Contractions")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 12. Common Mistakes
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Common Mistakes - Practice
print("Common Mistakes")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")

# %% [markdown]
# ## 13. Practice Conversations
#
# [Content to be added: Detailed grammar explanation]
#
# ### Examples:
# - Example 1
# - Example 2
# - Example 3
# - Example 4
#
# ### Key Grammar Points:
# - Point 1
# - Point 2
# - Point 3

# %%
# Practice Conversations - Practice
print("Practice Conversations")
print("=" * 60)

examples = [
    "Example sentence 1",
    "Example sentence 2",
    "Example sentence 3",
    "Example sentence 4"
]

for i, ex in enumerate(examples, 1):
    print(f"{i}. {ex}")

print("\nYour turn: Create sentences using this grammar point")
