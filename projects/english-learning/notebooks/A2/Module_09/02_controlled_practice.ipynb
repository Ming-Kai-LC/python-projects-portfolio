# %% [markdown]
# # Module 09: Time Sequencing (before, after, then, finally) - Phase 2: Controlled Practice
#
# ## Overview
# 83 exercises to master time sequencing (before, after, then, finally)
#
# **Total: 83 exercises** *(Enhanced for stronger grammar foundation)*

# %% [markdown]
# ## Exercise Set 1: Formation - Affirmative (9 exercises)
#
# **Focus:** Create affirmative sentences
#
# ### Instructions:
# Complete all 9 exercises below. Check your answers at the end.

# %%
# Exercise Set 1: Formation - Affirmative
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Affirmative")
print("=" * 60)

# 9 exercises
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 2: Formation - Negative (9 exercises)
#
# **Focus:** Create negative sentences
#
# ### Instructions:
# Complete all 9 exercises below. Check your answers at the end.

# %%
# Exercise Set 2: Formation - Negative
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Negative")
print("=" * 60)

# 9 exercises
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 3: Formation - Questions (9 exercises)
#
# **Focus:** Form questions correctly
#
# ### Instructions:
# Complete all 9 exercises below. Check your answers at the end.

# %%
# Exercise Set 3: Formation - Questions
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Questions")
print("=" * 60)

# 9 exercises
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 4: Short Answers (8 exercises)
#
# **Focus:** Give appropriate short answers
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 4: Short Answers
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Short Answers")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 5: Error Correction (8 exercises)
#
# **Focus:** Find and correct mistakes
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 5: Error Correction
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Error Correction")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 6: Gap Filling (8 exercises)
#
# **Focus:** Complete with correct forms
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 6: Gap Filling
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Gap Filling")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 7: Sentence Transformation (8 exercises)
#
# **Focus:** Convert between forms
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 7: Sentence Transformation
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Sentence Transformation")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 8: Context Matching (8 exercises)
#
# **Focus:** Choose appropriate form for context
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 8: Context Matching
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Context Matching")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 9: Time Expression Usage (8 exercises)
#
# **Focus:** Use time markers correctly
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 9: Time Expression Usage
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Time Expression Usage")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")

# %% [markdown]
# ## Exercise Set 10: Mixed Practice (8 exercises)
#
# **Focus:** Apply all skills together
#
# ### Instructions:
# Complete all 8 exercises below. Check your answers at the end.

# %%
# Exercise Set 10: Mixed Practice
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Mixed Practice")
print("=" * 60)

# 8 exercises
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Grammar exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
