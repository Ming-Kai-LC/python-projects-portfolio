# %% [markdown]
# # Module 09: Time Sequencing (before, after, then, finally) - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks

# %% [markdown]
# ## Task 1: Pair Interview
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 1: Pair Interview
print("Pair Interview")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Role-Play Scenario
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 2: Role-Play Scenario
print("Role-Play Scenario")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Group Discussion
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 3: Group Discussion
print("Group Discussion")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Information Gap Activity
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 4: Information Gap Activity
print("Information Gap Activity")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Problem Solving Task
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 5: Problem Solving Task
print("Problem Solving Task")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Presentation Activity
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 6: Presentation Activity
print("Presentation Activity")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Collaborative Project
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 7: Collaborative Project
print("Collaborative Project")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Real-World Simulation
#
# **Objective:** [Description to be added]
#
# ### Instructions:
# - Work in pairs or small groups
# - Use target grammar throughout
# - Ask and answer questions naturally
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - [Focus point 1]
# - [Focus point 2]
# - [Focus point 3]

# %%
# Task 8: Real-World Simulation
print("Real-World Simulation")
print("=" * 60)
print("\nUseful questions and prompts:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")
