# %% [markdown]
# # Module 20: Intensifiers and Descriptive Language - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on intensifiers

# %% [markdown]
# ## Task 1: Too or Enough? - Decision Making
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 1: Too or Enough? - Decision Making
print("Too or Enough? - Decision Making")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Intensifier Degrees Game
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 2: Intensifier Degrees Game
print("Intensifier Degrees Game")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Complaint Role Play (Too...)
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 3: Complaint Role Play (Too...)
print("Complaint Role Play (Too...)")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Satisfaction Survey (Enough...)
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 4: Satisfaction Survey (Enough...)
print("Satisfaction Survey (Enough...)")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Very vs Really - Emphasis Practice
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 5: Very vs Really - Emphasis Practice
print("Very vs Really - Emphasis Practice")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Setting Standards - What's Enough?
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 6: Setting Standards - What's Enough?
print("Setting Standards - What's Enough?")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Consumer Feedback - Using Intensifiers
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 7: Consumer Feedback - Using Intensifiers
print("Consumer Feedback - Using Intensifiers")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Describing Ideal Conditions
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# - Work in pairs or small groups
# - Use intensifiers throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use intensifiers naturally
# - Ask and answer questions
# - Give reasons for comparisons
# - Listen to others' opinions

# %%
# Task 8: Describing Ideal Conditions
print("Describing Ideal Conditions")
print("=" * 60)
print(f"\nUse intensifiers in this communicative task")
print("\nUseful patterns:")
print("- Pattern 1: [To be added]")
print("- Pattern 2: [To be added]")
print("- Pattern 3: [To be added]")
print("\nPrepare and practice with your partner!")
