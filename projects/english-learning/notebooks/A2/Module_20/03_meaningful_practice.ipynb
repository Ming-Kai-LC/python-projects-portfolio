# %% [markdown]
# # Module 20: Intensifiers and Descriptive Language - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using intensifiers in real contexts

# %% [markdown]
# ## Activity 1: Very vs Too - Making Distinctions
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 1: Very vs Too - Making Distinctions
print("Very vs Too - Making Distinctions")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 2: What's Enough and What Isn't?
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 2: What's Enough and What Isn't?
print("What's Enough and What Isn't?")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 3: Too Much of a Good Thing
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 3: Too Much of a Good Thing
print("Too Much of a Good Thing")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 4: Quite Interesting - British Understatement
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 4: Quite Interesting - British Understatement
print("Quite Interesting - British Understatement")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 5: Really Amazing Experiences
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 5: Really Amazing Experiences
print("Really Amazing Experiences")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 6: Not Enough Time/Money/Space
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 6: Not Enough Time/Money/Space
print("Not Enough Time/Money/Space")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 7: Too Expensive or Just Right?
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 7: Too Expensive or Just Right?
print("Too Expensive or Just Right?")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 8: Very Good vs Really Excellent
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 8: Very Good vs Really Excellent
print("Very Good vs Really Excellent")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 9: Enough is Enough - Setting Limits
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 9: Enough is Enough - Setting Limits
print("Enough is Enough - Setting Limits")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")

# %% [markdown]
# ## Activity 10: Intensifying Your Descriptions
#
# **Comparison Focus:** intensifiers
#
# ### Instructions:
# 1. Write 8-10 sentences using intensifiers
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: correct formation and spelling
#
# **Example:**
# [Model answer using intensifiers to be added]
#
# **Tips:**
# - Use real people, places, and things from your life
# - Compare across different categories (people, places, experiences)
# - Include reasons for your comparisons

# %%
# Activity 10: Intensifying Your Descriptions
print("Intensifying Your Descriptions")
print("=" * 60)
print(f"\nUse intensifiers to make personal comparisons")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember:")
print("- Check your spelling carefully")
print("- Use 'than' with comparatives")
print("- Use 'the' with superlatives")
print("\nShare with a partner and compare!")
