# %% [markdown]
# # Module 13: Don't Have To vs Mustn't - No Obligation vs Prohibition - Phase 2: Controlled Practice
#
# ## Overview
# 82 exercises to master don't have to/mustn't
#
# **Total: 82 exercises** *(Enhanced for modal verb accuracy)*
# **Focus:** no obligation, prohibition, not necessary, not allowed

# %% [markdown]
# ## Exercise Set 1: Formation - Affirmative (9 exercises)
#
# **Focus:** Create affirmative sentences with correct modal form
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 1: Formation - Affirmative
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Affirmative")
print("=" * 60)

# 9 exercises with don't have to/mustn't
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 2: Formation - Negative (9 exercises)
#
# **Focus:** Create negative sentences correctly
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 9 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 2: Formation - Negative
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Negative")
print("=" * 60)

# 9 exercises with don't have to/mustn't
for i in range(1, 9 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 3: Formation - Questions (8 exercises)
#
# **Focus:** Form questions with proper word order
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 3: Formation - Questions
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Formation - Questions")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 4: Short Answers (8 exercises)
#
# **Focus:** Give appropriate short answers
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 4: Short Answers
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Short Answers")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 5: Error Correction (8 exercises)
#
# **Focus:** Find and correct modal verb mistakes
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 5: Error Correction
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Error Correction")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 6: Gap Filling (8 exercises)
#
# **Focus:** Complete with correct modal forms
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 6: Gap Filling
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Gap Filling")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 7: Sentence Transformation (8 exercises)
#
# **Focus:** Convert between forms
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 7: Sentence Transformation
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Sentence Transformation")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 8: Context Matching (8 exercises)
#
# **Focus:** Choose appropriate modal for context
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 8: Context Matching
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Context Matching")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 9: Meaning Focus (8 exercises)
#
# **Focus:** Use modal based on intended meaning
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 9: Meaning Focus
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Meaning Focus")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")

# %% [markdown]
# ## Exercise Set 10: Mixed Practice (8 exercises)
#
# **Focus:** Apply all skills together
# **Modal:** don't have to/mustn't
#
# ### Instructions:
# Complete all 8 exercises below. Pay attention to modal verb rules!
#
# **Remember:**
# - Use base verb after don't have to/mustn't
# - No -s in third person
# - Check word order in questions

# %%
# Exercise Set 10: Mixed Practice
from projects.english_learning.utils.feedback_system import ExerciseValidator

validator = ExerciseValidator()
print("Mixed Practice")
print("=" * 60)

# 8 exercises with don't have to/mustn't
for i in range(1, 8 + 1):
    print(f"{i}. Exercise {i}: [Modal verb exercise to be added]")

print("\n[Detailed answers and explanations at end of notebook]")
print("\nValidation tip: Check that don't have to/mustn't is followed by base verb!")
