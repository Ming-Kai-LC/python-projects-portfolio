# %% [markdown]
# # Module 13: Don't Have To vs Mustn't - No Obligation vs Prohibition - Phase 3: Meaningful Practice
#
# ## Overview
# 10 personalized activities using don't have to/mustn't in real contexts

# %% [markdown]
# ## Activity 1: Understanding Signs and Rules
#
# **Modal Focus:** don't have to/mustn't
# **Context:** prohibition
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 1: Understanding Signs and Rules
print("Understanding Signs and Rules")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: prohibition")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 2: Freedoms and Prohibitions at School
#
# **Modal Focus:** don't have to/mustn't
# **Context:** not necessary
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 2: Freedoms and Prohibitions at School
print("Freedoms and Prohibitions at School")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: not necessary")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 3: Workplace Do's and Don'ts
#
# **Modal Focus:** don't have to/mustn't
# **Context:** not allowed
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 3: Workplace Do's and Don'ts
print("Workplace Do's and Don'ts")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: not allowed")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 4: Travel Restrictions and Freedoms
#
# **Modal Focus:** don't have to/mustn't
# **Context:** no obligation
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 4: Travel Restrictions and Freedoms
print("Travel Restrictions and Freedoms")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: no obligation")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 5: Library/Museum Rules
#
# **Modal Focus:** don't have to/mustn't
# **Context:** prohibition
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 5: Library/Museum Rules
print("Library/Museum Rules")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: prohibition")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 6: Traffic Laws - Must vs Don't Have To
#
# **Modal Focus:** don't have to/mustn't
# **Context:** not necessary
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 6: Traffic Laws - Must vs Don't Have To
print("Traffic Laws - Must vs Don't Have To")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: not necessary")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 7: Cultural Prohibitions
#
# **Modal Focus:** don't have to/mustn't
# **Context:** not allowed
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 7: Cultural Prohibitions
print("Cultural Prohibitions")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: not allowed")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 8: Hotel Rules and Policies
#
# **Modal Focus:** don't have to/mustn't
# **Context:** no obligation
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 8: Hotel Rules and Policies
print("Hotel Rules and Policies")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: no obligation")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 9: Park Regulations
#
# **Modal Focus:** don't have to/mustn't
# **Context:** prohibition
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 9: Park Regulations
print("Park Regulations")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: prohibition")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")

# %% [markdown]
# ## Activity 10: Restaurant Policies
#
# **Modal Focus:** don't have to/mustn't
# **Context:** not necessary
#
# ### Instructions:
# 1. Write 8-10 sentences using don't have to/mustn't
# 2. Use affirmative, negative, and question forms
# 3. Make it personal and realistic
# 4. Check: base verb after modal (no -s, no 'to')
#
# **Example:**
# [Model answer using don't have to/mustn't to be added]

# %%
# Activity 10: Restaurant Policies
print("Restaurant Policies")
print("=" * 60)
print(f"\nUse don't have to/mustn't to talk about: not necessary")
print("\nWrite your sentences below:")
print()

for j in range(1, 11):
    print(f"{j}. _________________________________")

print("\nRemember: don't have to/mustn't + base verb!")
