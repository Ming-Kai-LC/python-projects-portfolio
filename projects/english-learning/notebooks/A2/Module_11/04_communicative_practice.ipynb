# %% [markdown]
# # Module 11: Should/Shouldn't - Advice and Recommendations - Phase 4: Communicative Practice
#
# ## Overview
# 8 real-world communicative tasks focusing on advice, recommendations, opinions, suggestions

# %% [markdown]
# ## Task 1: Advice Clinic - Role Play
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** recommendations
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for recommendations
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 1: Advice Clinic - Role Play
print("Advice Clinic - Role Play")
print("=" * 60)
print(f"\nCommunicative Goal: recommendations")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 2: Problem Solving Discussion
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** opinions
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for opinions
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 2: Problem Solving Discussion
print("Problem Solving Discussion")
print("=" * 60)
print(f"\nCommunicative Goal: opinions")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 3: Lifestyle Improvement Plan
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** suggestions
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for suggestions
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 3: Lifestyle Improvement Plan
print("Lifestyle Improvement Plan")
print("=" * 60)
print(f"\nCommunicative Goal: suggestions")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 4: Advice for Newcomers
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** advice
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for advice
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 4: Advice for Newcomers
print("Advice for Newcomers")
print("=" * 60)
print(f"\nCommunicative Goal: advice")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 5: Should We or Shouldn't We? - Group Decision
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** recommendations
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for recommendations
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 5: Should We or Shouldn't We? - Group Decision
print("Should We or Shouldn't We? - Group Decision")
print("=" * 60)
print(f"\nCommunicative Goal: recommendations")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 6: Travel Planning Advice
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** opinions
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for opinions
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 6: Travel Planning Advice
print("Travel Planning Advice")
print("=" * 60)
print(f"\nCommunicative Goal: opinions")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 7: Agony Aunt Letters
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** suggestions
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for suggestions
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 7: Agony Aunt Letters
print("Agony Aunt Letters")
print("=" * 60)
print(f"\nCommunicative Goal: suggestions")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")

# %% [markdown]
# ## Task 8: Recommendation Presentation
#
# **Modal Focus:** should/shouldn't
# **Communicative Goal:** advice
#
# ### Instructions:
# - Work in pairs or small groups
# - Use should/shouldn't throughout the activity
# - Focus on natural communication
# - Present findings to the class
#
# **Time:** 15-20 minutes
#
# ### Language Focus:
# - Use should/shouldn't for advice
# - Ask and answer questions naturally
# - Give reasons for your answers

# %%
# Task 8: Recommendation Presentation
print("Recommendation Presentation")
print("=" * 60)
print(f"\nCommunicative Goal: advice")
print(f"\nUseful should/shouldn't questions:")
print("- Question 1: [To be added]")
print("- Question 2: [To be added]")
print("- Question 3: [To be added]")
print("\nPrepare and practice with your partner!")
